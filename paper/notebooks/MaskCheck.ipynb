# %%
import SimpleITK as sitk

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
img = sitk.ReadImage('/Users/joemarsilla/Documents/MASTRO/masks/HN1060.nrrd')

# %%
img = sitk.GetArrayFromImage(img)

# %%
img.shape
# Out:
# (134, 512, 512)

# %%
for i, slice_ in enumerate(img):
    if slice_.max()>0:
        print(slice_.max())
        plt.imshow(slice_)
        plt.show()
# Out:
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 3
# 1
# 1
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
