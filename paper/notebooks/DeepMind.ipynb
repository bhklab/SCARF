# %%
import SimpleITK as sitk
import numpy as np
import torch
import pandas as pd
import monai.metrics as met

# %%
# # data from analysis...
# metrics = pd.read_csv("/Users/jmarsill/ptl-oar-segmentation/paper/csv/OARensemble2021_deepmind.csv")
# # patient
# patients = list(metrics.Patient.unique())

# %%
# # patients
# # this file originally was saved in numpy...convert to .csv...
# import glob, nrrd, os
# vals = glob.glob("/Users/jmarsill/Documents/DEEPMIND/*_FULL*")

# %%
# vals.sort()
# # original custom order...
# chosen = ['BSTEM','SPCOR','ESOPH','LARYNX','MAND','LPAR','RPAR','LACOU','RACOU','RPLEX','LPLEX','LLENS','RLENS','LEYE','REYE','LOPTIC','ROPTIC','CHIASM','LIPS']
# # corresponding to what naming convention...
# ROIS = ["External", "GTVp", "LCTVn", "RCTVn", "Brainstem", "Esophagus",
#         "Larynx", "Cricoid_P", "OpticChiasm", "Glnd_Lacrimal_L",
#         "Glnd_Lacrimal_R", "Lens_L", "Lens_R", "Eye_L", "Eye_R",
#         "Nrv_Optic_L", "Nrv_Optic_R", "Parotid_L", "Parotid_R",
#         "SpinalCord", "Mandible_Bone", "Glnd_Submand_L",
#         "Glnd_Submand_R", "Cochlea_L", "Cochlea_R", "Lips",
#         "Spc_Retrophar_R", "Spc_Retrophar_L", "BrachialPlex_R",
#         "BrachialPlex_L", "Brain", "OralCavity", "Musc_Constrict_I",
#         "Musc_Constrict_S", "Musc_Constrict_M", "LEVEL_IA", "LEVEL_IB_RT",
#         "LEVEL_III_RT", "LEVEL_II_RT", "LEVEL_IV_RT", "LEVEL_VIIA_RT","LEVEL_V_RT",
#         "LEVEL_IB_LT","LEVEL_III_LT","LEVEL_II_LT","LEVEL_IV_LT","LEVEL_VIIA_LT","LEVEL_V_LT",
#         "LEVEL_IB", "LEVEL_II", "LEVEL_III", "LEVEL_IV", "LEVEL_V", "LEVEL_VIIA",
#         "CTVn", "BrachialPlex", "Parotid", "Glnd_Lacrimal", "Cochlea", "Spc_Retrophar", 
#         "Glnd_Submand", "Lens", "Eye", "Nrv_Optic"]
# order_ = [4,19,5,6,20,17,18,23,24,28,29,11,12,13,14,15,16,8,25]
# new_roi_names = [ROIS[i] for i in order_]

# %%
# len(chosen)

# %%
# import os, matplotlib.pyplot as plt

# %%
# # nrrd.write(new_path, mask, header={"study_oar":chosen[j], "volume": len(mask==1)})
# for i, val in enumerate(vals):
#     # i+=1
#     patient = patients[i]
#     # os.mkdir(f"/Users/jmarsill/Documents/DEEPMINDV2/{patient}/")
#     # os.mkdir(f"/Users/jmarsill/Documents/DEEPMINDV2/{patient}/structures")
#     mask_path = f"/Users/jmarsill/Documents/DEEPMIND/outs_{i}_FULL.npy"
#     img_path = f"/Users/jmarsill/Documents/DEEPMIND/input_{i}_FULL.npy"
#     mask = np.load(mask_path)
#     img = np.load(img_path)
#     print(mask.shape)
#     d_ = {}
#     for j, name in enumerate(new_roi_names):
#         mask_ = mask.copy()
#         mask_[mask != j+1] = 0
#         mask_[mask == j+1] = 1
#         new_path = f"/Users/jmarsill/Documents/DEEPMINDV2/{patient}/structures/{name}.nrrd"
#         nrrd.write(new_path, np.int8(mask_), header={"patient_id":patient, "model": "WOLNET_3D_ENS", "study_oar":name, "volume": len(mask_==1)}, compression_level=9)
#         d_[name] = len(mask_==1)
#         print(f"Saved {name} {j+1}")
#         # plt.figure()
#         # plt.imshow(mask_[100])
#         # plt.show()
#     # img_path = f"/Users/jmarsill/Documents/DEEPMINDV2/UPDATE/{patient}/CT_IMAGE.nrrd"
#     # nrrd.write(img_path, img, header={"patient_id":patient,  "model": "WOLNET_3D_ENS", "oar_volumes": d_})
#     # break

# %%
data = data = pd.read_csv('/Users/joemarsilla/Downloads/deep_.csv', index_col=0)

# %%
data.head()
# Out:
#                                                    0  \
# 0  /cluster/projects/radiomics/EXTERNAL/DeepMind/...
# 1  /cluster/projects/radiomics/EXTERNAL/DeepMind/...
# 2  /cluster/projects/radiomics/EXTERNAL/DeepMind/...
# 3  /cluster/projects/radiomics/EXTERNAL/DeepMind/...
# 4  /cluster/projects/radiomics/EXTERNAL/DeepMind/...
#
#                                                    1
# 0  /cluster/projects/radiomics/EXTERNAL/DeepMind/...
# 1  /cluster/projects/radiomics/EXTERNAL/DeepMind/...
# 2  /cluster/projects/radiomics/EXTERNAL/DeepMind/...
# 3  /cluster/projects/radiomics/EXTERNAL/DeepMind/...
# 4  /cluster/projects/radiomics/EXTERNAL/DeepMind/...

# %%
pats = list(data['0'])

# %%
p = [p.split('/')[-2] for p in pats]

# %%
p = list(set(p))

# %%
from collections import OrderedDict
p = OrderedDict((x, True) for x in p).keys()

# %%
p = list(p)

# %%
p
# Out:
# ['0522c0427',
#  '0522c0773',
#  '0522c0519',
#  '0522c0667',
#  '0522c0248',
#  'TCGA-CV-A6K0',
#  '0522c0251',
#  '0522c0419',
#  '0522c0768',
#  '0522c0457',
#  'TCGA-CV-A6JO',
#  'TCGA-CV-5978',
#  '0522c0659',
#  '0522c0727b',
#  'TCGA-CV-7236',
#  '0522c0057',
#  '0522c0727a',
#  '0522c0226',
#  'TCGA-CV-7245',
#  'TCGA-CV-7243',
#  '0522c0576',
#  '0522c0416',
#  'TCGA-CV-A6K1',
#  'TCGA-CV-A6JY',
#  '0522c0014',
#  '0522c0629',
#  '0522c0669',
#  '0522c0845',
#  '0522c0770',
#  '0522c0708',
#  '0522c0479',
#  '0522c0017',
#  'TCGA-CV-5977',
#  '0522c0331',
#  '0522c0161']

# %%
deep_classes = ['Brainstem','Lens-Lt', 'Lens-Rt', 'Mandible', 'Optic-Nerve-Lt', 'Optic-Nerve-Rt', 'Parotid-Lt', 'Parotid-Rt', 'Orbit-Lt', 'Orbit-Rt', 'Spinal-Cord', 'Spinal-Canal']
deep_classes2 = ['Brainstem','Lens_Lt', 'Lens_Rt', 'Mandible', 'Optic_Nerve_Lt', 'Optic_Nerve_Rt', 'Parotid_Lt', 'Parotid_Rt', 'Orbit_Lt', 'Orbit_Rt', 'Spinal_Cord', 'Spinal_Canal']
index_ = [1, 12, 13, 5, 16, 17, 6, 7, 14, 15, 2, 2]
chosen = ['BSTEM','SPCOR','ESOPH','LARYNX','MAND','LPAR','RPAR','LACOU','RACOU','RPLEX','LPLEX','LLENS','RLENS','LEYE','REYE','LOPTIC','ROPTIC','CHIASM','LIPS']

# %%
len(index_)
# Out:
# 12

# %%
len(deep_classes)
# Out:
# 12

# %%
# import torch, numpy as np, warnings
# this is the function to one-hot-encode data
def onehot(outs, targ, argmax=True):
    # Metrics requiring one hot encoded targets, pass through sigmoid or softmax
    # convert to one hot encoded target...
    shape = targ.size()
    print(len(shape), shape, outs.size())
    batch = shape[0]
    # calculate argmax...
    if argmax is True:
        outs = torch.softmax(outs, dim=1)
        outs = torch.argmax(outs, dim=1)
    
    class_ = int(torch.max(targ).item())
    print(class_)
    
    if len(shape) == 4:
        sh = (batch, class_ + 1, shape[1], shape[2], shape[3])
        print(sh)
        targets_dice = torch.zeros(sh, dtype=torch.float)
        targets_out = torch.zeros(sh, dtype=torch.float)
    else:
        sh = (1, class_ + 1, shape[0], shape[1], shape[2])
        print(sh)
        targets_dice = torch.zeros(sh, dtype=torch.float)
        targets_out = torch.zeros(sh, dtype=torch.float)

    for i in range( class_ + 1):
        targets_dice[0, i][targ[0] == i] = 1
        targets_out[0, i][outs[0] == i] = 1

    return targets_out, targets_dice

# %%
def resample_sitk(image, mode="linear", new_spacing=None, filter=False ): # new_spacing=np.array((1.0, 1.0, 2.0)) , filter=True
    if new_spacing is not None: # originally taken from https://github.com/SimpleITK/SimpleITK/issues/561
        resample = sitk.ResampleImageFilter()
        if mode == "linear":
            resample.SetInterpolator = sitk.sitkLinear  # use linear to resample image
        else: # use sitkNearestNeighbor interpolation # best for masks
            resample.SetInterpolator = sitk.sitkNearestNeighbor
        orig_size = np.array(image.GetSize(), dtype=np.int)
        orig_spacing = np.array(image.GetSpacing())
        resample.SetOutputDirection(image.GetDirection())
        resample.SetOutputOrigin(image.GetOrigin())
        resample.SetOutputPixelType(image.GetPixelIDValue())
        new_spacing = new_spacing
        resample.SetOutputSpacing(new_spacing)
        new_size = orig_size * (orig_spacing / new_spacing)
        new_size = np.ceil(new_size).astype(np.int)
        new_size = [int(s) for s in new_size]
        resample.SetSize(new_size)
        if filter is True: # fights artifacts produced by analaising # only do this when resampling image (not mask...)
            img = resample.Execute(sitk.SmoothingRecursiveGaussian(image, 2.0))
        else:
            img = resample.Execute(image)
    else: # do nothing to the image...
        img = image
    return img

# %%
oars = []
deep_oars = []
dce =  []
hd =   []
sd =   []
ob = []
p_ = []

# %%
# path of folders...
observer = 'radiographer'
path = f'/Users/joemarsilla/Documents/DeepMind/{observer}/' 

for i, pat in enumerate(p):
    path_ = path+pat+'/segmentations/'
    # load subsequent patient outputs from model...
    out_path = f"/Users/joemarsilla/Downloads/deepmind_ai_preds/outs_{i}_FULL.npy"
    outputs = torch.from_numpy(np.load(out_path))
#     targets = torch.from_numpy(np.load(out_path.replace('outs', 'in')))
    outputs, _ = onehot(outputs.unsqueeze(0), outputs.unsqueeze(0), argmax=False)
    
    for k, val in enumerate(index_):
        try:
            targ = sitk.ReadImage(path_+deep_classes[k]+'.nrrd')
        except Exception:
            targ = sitk.ReadImage(path_+deep_classes2[k]+'.nrrd')
#       img = self.resample_sitk(img, new_spacing=np.array((1.0, 1.0, 2.0)))
#         targ = resample_sitk(targ, mode="nearest", new_spacing=np.array((1.0, 1.0, 2.0)))
        targ = torch.tensor(sitk.GetArrayFromImage(targ))
        outs = outputs[0,val]
        dc = met.compute_meandice(outs.unsqueeze(0).unsqueeze(0), targ.unsqueeze(0).unsqueeze(0))
        h  = met.compute_hausdorff_distance(outs.unsqueeze(0).unsqueeze(0), targ.unsqueeze(0).unsqueeze(0), percentile=95, include_background=False)
        s  = met.compute_average_surface_distance(outs.unsqueeze(0).unsqueeze(0), targ.unsqueeze(0).unsqueeze(0), include_background=False)
        print(chosen[val-1], dc, h)
        # save metrics...
        dce.append(dc[0][0].item())
        hd.append(h[0][0].item())
        sd.append(s[0][0].item())
        ob.append(observer)
        deep_oars.append(deep_classes[k])
        oars.append(chosen[val-1])
        p_.append(pat)
# Out:
# 4 torch.Size([1, 170, 512, 512]) torch.Size([1, 170, 512, 512])
# 19
# (1, 20, 170, 512, 512)
# BSTEM tensor([[0.7911]]) tensor([[3.1623]], dtype=torch.float64)
# LLENS tensor([[0.6154]]) tensor([[1.6485]], dtype=torch.float64)
# RLENS tensor([[0.5324]]) tensor([[2.]], dtype=torch.float64)
# MAND tensor([[0.8577]]) tensor([[2.]], dtype=torch.float64)
# LOPTIC tensor([[0.5146]]) tensor([[6.3521]], dtype=torch.float64)
# ROPTIC tensor([[0.6011]]) tensor([[2.]], dtype=torch.float64)
# LPAR tensor([[0.8657]]) tensor([[3.]], dtype=torch.float64)
# RPAR tensor([[0.8697]]) tensor([[2.4495]], dtype=torch.float64)
# LEYE tensor([[0.7833]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.7931]]) tensor([[2.2361]], dtype=torch.float64)
# SPCOR tensor([[0.7014]]) tensor([[4.3008]], dtype=torch.float64)
# SPCOR tensor([[0.6797]]) tensor([[6.7823]], dtype=torch.float64)
# 4 torch.Size([1, 168, 512, 512]) torch.Size([1, 168, 512, 512])
# 19
# (1, 20, 168, 512, 512)
# BSTEM tensor([[0.7883]]) tensor([[4.2426]], dtype=torch.float64)
# LLENS tensor([[0.7285]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.6645]]) tensor([[2.]], dtype=torch.float64)
# MAND tensor([[0.9166]]) tensor([[3.]], dtype=torch.float64)
# LOPTIC tensor([[0.5117]]) tensor([[2.2361]], dtype=torch.float64)
# ROPTIC tensor([[0.5622]]) tensor([[1.7990]], dtype=torch.float64)
# LPAR tensor([[0.8923]]) tensor([[2.2361]], dtype=torch.float64)
# RPAR tensor([[0.8849]]) tensor([[3.]], dtype=torch.float64)
# LEYE tensor([[0.8402]]) tensor([[2.]], dtype=torch.float64)
# REYE tensor([[0.8353]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.7172]]) tensor([[3.]], dtype=torch.float64)
# SPCOR tensor([[0.7715]]) tensor([[4.5826]], dtype=torch.float64)
# 4 torch.Size([1, 188, 512, 512]) torch.Size([1, 188, 512, 512])
# 19
# (1, 20, 188, 512, 512)
# BSTEM tensor([[0.8340]]) tensor([[3.7417]], dtype=torch.float64)
# LLENS tensor([[0.6667]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.5333]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9038]]) tensor([[1.4142]], dtype=torch.float64)
# LOPTIC tensor([[0.5532]]) tensor([[3.7417]], dtype=torch.float64)
# ROPTIC tensor([[0.6573]]) tensor([[2.3428]], dtype=torch.float64)
# LPAR tensor([[0.8739]]) tensor([[2.8284]], dtype=torch.float64)
# RPAR tensor([[0.8395]]) tensor([[4.2426]], dtype=torch.float64)
# LEYE tensor([[0.8321]]) tensor([[2.]], dtype=torch.float64)
# REYE tensor([[0.8384]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.6226]]) tensor([[7.1763]], dtype=torch.float64)
# SPCOR tensor([[0.6919]]) tensor([[8.6603]], dtype=torch.float64)
# 4 torch.Size([1, 146, 512, 512]) torch.Size([1, 146, 512, 512])
# 19
# (1, 20, 146, 512, 512)
# BSTEM tensor([[0.8027]]) tensor([[3.6056]], dtype=torch.float64)
# LLENS tensor([[0.6632]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.6818]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9101]]) tensor([[1.4142]], dtype=torch.float64)
# LOPTIC tensor([[0.5402]]) tensor([[2.]], dtype=torch.float64)
# ROPTIC tensor([[0.6131]]) tensor([[2.]], dtype=torch.float64)
# LPAR tensor([[0.8438]]) tensor([[3.3166]], dtype=torch.float64)
# RPAR tensor([[0.8707]]) tensor([[4.6904]], dtype=torch.float64)
# LEYE tensor([[0.8537]]) tensor([[2.]], dtype=torch.float64)
# REYE tensor([[0.8627]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.6836]]) tensor([[2.8284]], dtype=torch.float64)
# SPCOR tensor([[0.7214]]) tensor([[5.8310]], dtype=torch.float64)
# 4 torch.Size([1, 176, 512, 512]) torch.Size([1, 176, 512, 512])
# 19
# (1, 20, 176, 512, 512)
# BSTEM tensor([[0.7214]]) tensor([[5.0990]], dtype=torch.float64)
# LLENS tensor([[0.5469]]) tensor([[2.]], dtype=torch.float64)
# RLENS tensor([[0.5664]]) tensor([[2.]], dtype=torch.float64)
# MAND tensor([[0.9047]]) tensor([[2.]], dtype=torch.float64)
# LOPTIC tensor([[0.5187]]) tensor([[4.2187]], dtype=torch.float64)
# ROPTIC tensor([[0.5229]]) tensor([[2.9725]], dtype=torch.float64)
# LPAR tensor([[0.8690]]) tensor([[2.4495]], dtype=torch.float64)
# RPAR tensor([[0.8784]]) tensor([[2.2361]], dtype=torch.float64)
# LEYE tensor([[0.8432]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8545]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.6879]]) tensor([[3.1623]], dtype=torch.float64)
# SPCOR tensor([[0.7253]]) tensor([[5.3852]], dtype=torch.float64)
# 4 torch.Size([1, 157, 512, 512]) torch.Size([1, 157, 512, 512])
# 19
# (1, 20, 157, 512, 512)
# BSTEM tensor([[0.8756]]) tensor([[2.8284]], dtype=torch.float64)
# LLENS tensor([[0.6461]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.6569]]) tensor([[1.6208]], dtype=torch.float64)
# MAND tensor([[0.9316]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.6361]]) tensor([[2.9056]], dtype=torch.float64)
# ROPTIC tensor([[0.6419]]) tensor([[5.0248]], dtype=torch.float64)
# LPAR tensor([[0.8954]]) tensor([[2.2361]], dtype=torch.float64)
# RPAR tensor([[0.8482]]) tensor([[7.0711]], dtype=torch.float64)
# LEYE tensor([[0.8487]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8470]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.6933]]) tensor([[3.]], dtype=torch.float64)
# SPCOR tensor([[0.7542]]) tensor([[5.4772]], dtype=torch.float64)
# 4 torch.Size([1, 119, 512, 512]) torch.Size([1, 119, 512, 512])
# 19
# (1, 20, 119, 512, 512)
# BSTEM tensor([[0.7857]]) tensor([[3.6056]], dtype=torch.float64)
# LLENS tensor([[0.4373]]) tensor([[2.2361]], dtype=torch.float64)
# RLENS tensor([[0.5515]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9277]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.5521]]) tensor([[3.1623]], dtype=torch.float64)
# ROPTIC tensor([[0.5569]]) tensor([[2.2361]], dtype=torch.float64)
# LPAR tensor([[0.8645]]) tensor([[2.8284]], dtype=torch.float64)
# RPAR tensor([[0.8713]]) tensor([[3.1623]], dtype=torch.float64)
# LEYE tensor([[0.8243]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8298]]) tensor([[2.2361]], dtype=torch.float64)
# SPCOR tensor([[0.6549]]) tensor([[3.1623]], dtype=torch.float64)
# SPCOR tensor([[0.7493]]) tensor([[5.]], dtype=torch.float64)
# 4 torch.Size([1, 179, 512, 512]) torch.Size([1, 179, 512, 512])
# 19
# (1, 20, 179, 512, 512)
# BSTEM tensor([[0.7898]]) tensor([[3.7417]], dtype=torch.float64)
# LLENS tensor([[0.5594]]) tensor([[2.]], dtype=torch.float64)
# RLENS tensor([[0.7143]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9190]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.5295]]) tensor([[3.8922]], dtype=torch.float64)
# ROPTIC tensor([[0.5346]]) tensor([[2.]], dtype=torch.float64)
# LPAR tensor([[0.7254]]) tensor([[9.5315]], dtype=torch.float64)
# RPAR tensor([[0.7194]]) tensor([[10.0598]], dtype=torch.float64)
# LEYE tensor([[0.7804]]) tensor([[2.4495]], dtype=torch.float64)
# REYE tensor([[0.8316]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.6308]]) tensor([[3.]], dtype=torch.float64)
# SPCOR tensor([[0.7302]]) tensor([[6.1644]], dtype=torch.float64)
# 4 torch.Size([1, 161, 512, 512]) torch.Size([1, 161, 512, 512])
# 19
# (1, 20, 161, 512, 512)
# BSTEM tensor([[0.8033]]) tensor([[3.]], dtype=torch.float64)
# LLENS tensor([[0.5888]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.5730]]) tensor([[1.7321]], dtype=torch.float64)
# MAND tensor([[0.8825]]) tensor([[1.4142]], dtype=torch.float64)
# LOPTIC tensor([[0.5465]]) tensor([[2.2361]], dtype=torch.float64)
# ROPTIC tensor([[0.5888]]) tensor([[2.4495]], dtype=torch.float64)
# LPAR tensor([[0.8626]]) tensor([[2.2361]], dtype=torch.float64)
# RPAR tensor([[0.8932]]) tensor([[2.2361]], dtype=torch.float64)
# LEYE tensor([[0.7725]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.7611]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.7201]]) tensor([[3.]], dtype=torch.float64)
# SPCOR tensor([[0.7538]]) tensor([[4.2426]], dtype=torch.float64)
# 4 torch.Size([1, 181, 512, 512]) torch.Size([1, 181, 512, 512])
# 19
# (1, 20, 181, 512, 512)
# BSTEM tensor([[0.8090]]) tensor([[3.]], dtype=torch.float64)
# LLENS tensor([[0.5198]]) tensor([[2.]], dtype=torch.float64)
# RLENS tensor([[0.5600]]) tensor([[2.]], dtype=torch.float64)
# MAND tensor([[0.8822]]) tensor([[1.4142]], dtype=torch.float64)
# LOPTIC tensor([[0.3979]]) tensor([[2.2361]], dtype=torch.float64)
# ROPTIC tensor([[0.4641]]) tensor([[2.]], dtype=torch.float64)
# LPAR tensor([[0.8297]]) tensor([[3.]], dtype=torch.float64)
# RPAR tensor([[0.8943]]) tensor([[2.4495]], dtype=torch.float64)
# LEYE tensor([[0.8152]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.7978]]) tensor([[2.2361]], dtype=torch.float64)
# SPCOR tensor([[0.6964]]) tensor([[3.]], dtype=torch.float64)
# SPCOR tensor([[0.7437]]) tensor([[5.]], dtype=torch.float64)
# 4 torch.Size([1, 164, 512, 512]) torch.Size([1, 164, 512, 512])
# 19
# (1, 20, 164, 512, 512)
# BSTEM tensor([[0.7619]]) tensor([[4.4721]], dtype=torch.float64)
# LLENS tensor([[0.6467]]) tensor([[2.]], dtype=torch.float64)
# RLENS tensor([[0.5678]]) tensor([[2.]], dtype=torch.float64)
# MAND tensor([[0.9312]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.5605]]) tensor([[9.9121]], dtype=torch.float64)
# ROPTIC tensor([[0.5841]]) tensor([[7.0876]], dtype=torch.float64)
# LPAR tensor([[0.7629]]) tensor([[7.4833]], dtype=torch.float64)
# RPAR tensor([[0.7268]]) tensor([[7.3485]], dtype=torch.float64)
# LEYE tensor([[0.8376]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8304]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.6663]]) tensor([[2.8284]], dtype=torch.float64)
# SPCOR tensor([[0.7538]]) tensor([[7.4833]], dtype=torch.float64)
# 4 torch.Size([1, 145, 512, 512]) torch.Size([1, 145, 512, 512])
# 19
# (1, 20, 145, 512, 512)
# BSTEM tensor([[0.7836]]) tensor([[3.7417]], dtype=torch.float64)
# LLENS tensor([[0.3226]]) tensor([[3.6056]], dtype=torch.float64)
# RLENS tensor([[0.4753]]) tensor([[3.]], dtype=torch.float64)
# MAND tensor([[0.9319]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.6693]]) tensor([[1.9732]], dtype=torch.float64)
# ROPTIC tensor([[0.6280]]) tensor([[1.5413]], dtype=torch.float64)
# LPAR tensor([[0.8414]]) tensor([[4.1231]], dtype=torch.float64)
# RPAR tensor([[0.8009]]) tensor([[3.6056]], dtype=torch.float64)
# LEYE tensor([[0.8447]]) tensor([[2.]], dtype=torch.float64)
# REYE tensor([[0.8544]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.7205]]) tensor([[2.4495]], dtype=torch.float64)
# SPCOR tensor([[0.7862]]) tensor([[4.4721]], dtype=torch.float64)
# 4 torch.Size([1, 165, 512, 512]) torch.Size([1, 165, 512, 512])
# 19
# (1, 20, 165, 512, 512)
# BSTEM tensor([[0.8288]]) tensor([[3.]], dtype=torch.float64)
# LLENS tensor([[0.6829]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.7037]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9209]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.6295]]) tensor([[3.6736]], dtype=torch.float64)
# ROPTIC tensor([[0.5998]]) tensor([[2.2361]], dtype=torch.float64)
# LPAR tensor([[0.8451]]) tensor([[3.1854]], dtype=torch.float64)
# RPAR tensor([[0.8533]]) tensor([[2.8284]], dtype=torch.float64)
# LEYE tensor([[0.8098]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8427]]) tensor([[2.1298]], dtype=torch.float64)
# SPCOR tensor([[0.6197]]) tensor([[3.]], dtype=torch.float64)
# SPCOR tensor([[0.7553]]) tensor([[5.0990]], dtype=torch.float64)
# 4 torch.Size([1, 437, 512, 512]) torch.Size([1, 437, 512, 512])
# 19
# (1, 20, 437, 512, 512)
# BSTEM tensor([[0.7527]]) tensor([[4.4608]], dtype=torch.float64)
# LLENS tensor([[0.]]) tensor([[nan]], dtype=torch.float64)
# RLENS tensor([[0.]]) tensor([[nan]], dtype=torch.float64)
# MAND tensor([[0.7258]]) tensor([[327.5683]], dtype=torch.float64)
# LOPTIC tensor([[0.2786]]) tensor([[20.5023]], dtype=torch.float64)
# ROPTIC tensor([[0.4296]]) tensor([[9.8791]], dtype=torch.float64)
# LPAR tensor([[0.8308]]) tensor([[236.4022]], dtype=torch.float64)
# RPAR tensor([[0.8522]]) tensor([[312.3043]], dtype=torch.float64)
# LEYE tensor([[0.5030]]) tensor([[13.]], dtype=torch.float64)
# REYE tensor([[0.7723]]) tensor([[7.]], dtype=torch.float64)
# SPCOR tensor([[0.5240]]) tensor([[57.3149]], dtype=torch.float64)
# SPCOR tensor([[0.5216]]) tensor([[38.9487]], dtype=torch.float64)
# 4 torch.Size([1, 127, 512, 512]) torch.Size([1, 127, 512, 512])
# 19
# (1, 20, 127, 512, 512)
# BSTEM tensor([[0.7366]]) tensor([[4.]], dtype=torch.float64)
# LLENS tensor([[0.5735]]) tensor([[2.]], dtype=torch.float64)
# RLENS tensor([[0.6166]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9328]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.5817]]) tensor([[2.]], dtype=torch.float64)
# ROPTIC tensor([[0.6345]]) tensor([[1.7321]], dtype=torch.float64)
# LPAR tensor([[0.8561]]) tensor([[18.6984]], dtype=torch.float64)
# RPAR tensor([[0.8846]]) tensor([[3.]], dtype=torch.float64)
# LEYE tensor([[0.8302]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8202]]) tensor([[2.2361]], dtype=torch.float64)
# SPCOR tensor([[0.6394]]) tensor([[3.1460]], dtype=torch.float64)
# SPCOR tensor([[0.7218]]) tensor([[5.3852]], dtype=torch.float64)
# 4 torch.Size([1, 145, 512, 512]) torch.Size([1, 145, 512, 512])
# 19
# (1, 20, 145, 512, 512)
# BSTEM tensor([[0.8131]]) tensor([[4.]], dtype=torch.float64)
# LLENS tensor([[0.7356]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.5625]]) tensor([[2.]], dtype=torch.float64)
# MAND tensor([[0.9458]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.5977]]) tensor([[2.]], dtype=torch.float64)
# ROPTIC tensor([[0.5601]]) tensor([[1.8928]], dtype=torch.float64)
# LPAR tensor([[0.7736]]) tensor([[5.0990]], dtype=torch.float64)
# RPAR tensor([[0.8593]]) tensor([[5.0990]], dtype=torch.float64)
# LEYE tensor([[0.8404]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8721]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.7151]]) tensor([[2.8284]], dtype=torch.float64)
# SPCOR tensor([[0.7439]]) tensor([[5.4772]], dtype=torch.float64)
# 4 torch.Size([1, 437, 512, 512]) torch.Size([1, 437, 512, 512])
# 18
# (1, 19, 437, 512, 512)
# BSTEM tensor([[0.8449]]) tensor([[3.6056]], dtype=torch.float64)
# LLENS tensor([[0.]]) tensor([[nan]], dtype=torch.float64)
# RLENS tensor([[0.]]) tensor([[nan]], dtype=torch.float64)
# MAND tensor([[0.6123]]) tensor([[342.8108]], dtype=torch.float64)
# LOPTIC tensor([[0.4593]]) tensor([[3.6192]], dtype=torch.float64)
# ROPTIC tensor([[0.5798]]) tensor([[2.2361]], dtype=torch.float64)
# LPAR tensor([[0.7938]]) tensor([[8.1240]], dtype=torch.float64)
# RPAR tensor([[0.8254]]) tensor([[10.0474]], dtype=torch.float64)
# LEYE tensor([[0.4114]]) tensor([[15.]], dtype=torch.float64)
# REYE tensor([[0.5221]]) tensor([[13.]], dtype=torch.float64)
# SPCOR tensor([[0.4860]]) tensor([[64.2884]], dtype=torch.float64)
# SPCOR tensor([[0.5117]]) tensor([[42.4853]], dtype=torch.float64)
# 4 torch.Size([1, 162, 512, 512]) torch.Size([1, 162, 512, 512])
# 19
# (1, 20, 162, 512, 512)
# BSTEM tensor([[0.7254]]) tensor([[5.]], dtype=torch.float64)
# LLENS tensor([[0.5756]]) tensor([[2.2361]], dtype=torch.float64)
# RLENS tensor([[0.6228]]) tensor([[1.8124]], dtype=torch.float64)
# MAND tensor([[0.9032]]) tensor([[1.4142]], dtype=torch.float64)
# LOPTIC tensor([[0.5969]]) tensor([[1.7321]], dtype=torch.float64)
# ROPTIC tensor([[0.5592]]) tensor([[2.2361]], dtype=torch.float64)
# LPAR tensor([[0.8552]]) tensor([[4.1231]], dtype=torch.float64)
# RPAR tensor([[0.8420]]) tensor([[3.6056]], dtype=torch.float64)
# LEYE tensor([[0.7674]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.7721]]) tensor([[2.2361]], dtype=torch.float64)
# SPCOR tensor([[0.7003]]) tensor([[3.]], dtype=torch.float64)
# SPCOR tensor([[0.7465]]) tensor([[4.8990]], dtype=torch.float64)
# 4 torch.Size([1, 173, 512, 512]) torch.Size([1, 173, 512, 512])
# 19
# (1, 20, 173, 512, 512)
# BSTEM tensor([[0.8129]]) tensor([[3.3166]], dtype=torch.float64)
# LLENS tensor([[0.6627]]) tensor([[2.]], dtype=torch.float64)
# RLENS tensor([[0.6866]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9154]]) tensor([[1.4142]], dtype=torch.float64)
# LOPTIC tensor([[0.5403]]) tensor([[6.3363]], dtype=torch.float64)
# ROPTIC tensor([[0.5609]]) tensor([[4.8990]], dtype=torch.float64)
# LPAR tensor([[0.8386]]) tensor([[3.7417]], dtype=torch.float64)
# RPAR tensor([[0.8629]]) tensor([[2.8284]], dtype=torch.float64)
# LEYE tensor([[0.8079]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8416]]) tensor([[2.4495]], dtype=torch.float64)
# SPCOR tensor([[0.7039]]) tensor([[2.4495]], dtype=torch.float64)
# SPCOR tensor([[0.7400]]) tensor([[6.7082]], dtype=torch.float64)
# 4 torch.Size([1, 165, 512, 512]) torch.Size([1, 165, 512, 512])
# 19
# (1, 20, 165, 512, 512)
# BSTEM tensor([[0.8206]]) tensor([[3.6056]], dtype=torch.float64)
# LLENS tensor([[0.5798]]) tensor([[1.7321]], dtype=torch.float64)
# RLENS tensor([[0.6667]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9189]]) tensor([[1.4142]], dtype=torch.float64)
# LOPTIC tensor([[0.7257]]) tensor([[1.4142]], dtype=torch.float64)
# ROPTIC tensor([[0.7071]]) tensor([[1.4142]], dtype=torch.float64)
# LPAR tensor([[0.9105]]) tensor([[2.2361]], dtype=torch.float64)
# RPAR tensor([[0.8877]]) tensor([[3.1623]], dtype=torch.float64)
# LEYE tensor([[0.8781]]) tensor([[1.7321]], dtype=torch.float64)
# REYE tensor([[0.8782]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.6529]]) tensor([[3.2935]], dtype=torch.float64)
# SPCOR tensor([[0.6892]]) tensor([[6.]], dtype=torch.float64)
# 4 torch.Size([1, 204, 512, 512]) torch.Size([1, 204, 512, 512])
# 19
# (1, 20, 204, 512, 512)
# BSTEM tensor([[0.7972]]) tensor([[3.4641]], dtype=torch.float64)
# LLENS tensor([[0.6777]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.6667]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9297]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.5732]]) tensor([[1.4142]], dtype=torch.float64)
# ROPTIC tensor([[0.5972]]) tensor([[1.7321]], dtype=torch.float64)
# LPAR tensor([[0.8606]]) tensor([[2.4495]], dtype=torch.float64)
# RPAR tensor([[0.8851]]) tensor([[2.2361]], dtype=torch.float64)
# LEYE tensor([[0.8753]]) tensor([[2.]], dtype=torch.float64)
# REYE tensor([[0.8765]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.6681]]) tensor([[3.]], dtype=torch.float64)
# SPCOR tensor([[0.6484]]) tensor([[6.0828]], dtype=torch.float64)
# 4 torch.Size([1, 184, 512, 512]) torch.Size([1, 184, 512, 512])
# 19
# (1, 20, 184, 512, 512)
# BSTEM tensor([[0.7093]]) tensor([[4.3589]], dtype=torch.float64)
# LLENS tensor([[0.5907]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.4000]]) tensor([[2.4495]], dtype=torch.float64)
# MAND tensor([[0.9167]]) tensor([[1.4142]], dtype=torch.float64)
# LOPTIC tensor([[0.4994]]) tensor([[2.2361]], dtype=torch.float64)
# ROPTIC tensor([[0.4341]]) tensor([[2.4495]], dtype=torch.float64)
# LPAR tensor([[0.8680]]) tensor([[4.6904]], dtype=torch.float64)
# RPAR tensor([[0.8842]]) tensor([[3.1217]], dtype=torch.float64)
# LEYE tensor([[0.8301]]) tensor([[2.4175]], dtype=torch.float64)
# REYE tensor([[0.8813]]) tensor([[2.2361]], dtype=torch.float64)
# SPCOR tensor([[0.7282]]) tensor([[2.8284]], dtype=torch.float64)
# SPCOR tensor([[0.7174]]) tensor([[5.6569]], dtype=torch.float64)
# 4 torch.Size([1, 165, 512, 512]) torch.Size([1, 165, 512, 512])
# 19
# (1, 20, 165, 512, 512)
# BSTEM tensor([[0.8028]]) tensor([[4.2426]], dtype=torch.float64)
# LLENS tensor([[0.7181]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.6645]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9333]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.4802]]) tensor([[3.7212]], dtype=torch.float64)
# ROPTIC tensor([[0.4656]]) tensor([[3.2375]], dtype=torch.float64)
# LPAR tensor([[0.8884]]) tensor([[2.2361]], dtype=torch.float64)
# RPAR tensor([[0.8701]]) tensor([[2.8284]], dtype=torch.float64)
# LEYE tensor([[0.8546]]) tensor([[2.]], dtype=torch.float64)
# REYE tensor([[0.8616]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.7008]]) tensor([[2.8284]], dtype=torch.float64)
# SPCOR tensor([[0.7374]]) tensor([[6.4031]], dtype=torch.float64)
# 4 torch.Size([1, 130, 512, 512]) torch.Size([1, 130, 512, 512])
# 19
# (1, 20, 130, 512, 512)
# BSTEM tensor([[0.7109]]) tensor([[5.]], dtype=torch.float64)
# LLENS tensor([[0.6300]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.7427]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9157]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.5482]]) tensor([[3.6056]], dtype=torch.float64)
# ROPTIC tensor([[0.5638]]) tensor([[5.0990]], dtype=torch.float64)
# LPAR tensor([[0.8364]]) tensor([[5.2245]], dtype=torch.float64)
# RPAR tensor([[0.8579]]) tensor([[3.1623]], dtype=torch.float64)
# LEYE tensor([[0.8158]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8328]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.7317]]) tensor([[2.2361]], dtype=torch.float64)
# SPCOR tensor([[0.7538]]) tensor([[5.4772]], dtype=torch.float64)
# 4 torch.Size([1, 159, 512, 512]) torch.Size([1, 159, 512, 512])
# 19
# (1, 20, 159, 512, 512)
# BSTEM tensor([[0.8122]]) tensor([[3.]], dtype=torch.float64)
# LLENS tensor([[0.4863]]) tensor([[2.]], dtype=torch.float64)
# RLENS tensor([[0.6067]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9015]]) tensor([[1.4142]], dtype=torch.float64)
# LOPTIC tensor([[0.5316]]) tensor([[2.]], dtype=torch.float64)
# ROPTIC tensor([[0.5037]]) tensor([[2.2361]], dtype=torch.float64)
# LPAR tensor([[0.7808]]) tensor([[13.1529]], dtype=torch.float64)
# RPAR tensor([[0.8525]]) tensor([[3.7417]], dtype=torch.float64)
# LEYE tensor([[0.8004]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8035]]) tensor([[2.2361]], dtype=torch.float64)
# SPCOR tensor([[0.7255]]) tensor([[2.4495]], dtype=torch.float64)
# SPCOR tensor([[0.7469]]) tensor([[5.6569]], dtype=torch.float64)
# 4 torch.Size([1, 136, 512, 512]) torch.Size([1, 136, 512, 512])
# 19
# (1, 20, 136, 512, 512)
# BSTEM tensor([[0.8290]]) tensor([[3.1623]], dtype=torch.float64)
# LLENS tensor([[0.6729]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.6970]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.8876]]) tensor([[1.4142]], dtype=torch.float64)
# LOPTIC tensor([[0.6269]]) tensor([[1.8526]], dtype=torch.float64)
# ROPTIC tensor([[0.6659]]) tensor([[2.]], dtype=torch.float64)
# LPAR tensor([[0.8395]]) tensor([[4.1231]], dtype=torch.float64)
# RPAR tensor([[0.8023]]) tensor([[4.1231]], dtype=torch.float64)
# LEYE tensor([[0.8024]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8210]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.7822]]) tensor([[2.2361]], dtype=torch.float64)
# SPCOR tensor([[0.7171]]) tensor([[6.1644]], dtype=torch.float64)
# 4 torch.Size([1, 137, 512, 512]) torch.Size([1, 137, 512, 512])
# 19
# (1, 20, 137, 512, 512)
# BSTEM tensor([[0.8293]]) tensor([[4.2426]], dtype=torch.float64)
# LLENS tensor([[0.6480]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.6931]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9372]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.6329]]) tensor([[1.4142]], dtype=torch.float64)
# ROPTIC tensor([[0.6198]]) tensor([[1.7321]], dtype=torch.float64)
# LPAR tensor([[0.8414]]) tensor([[6.1644]], dtype=torch.float64)
# RPAR tensor([[0.8555]]) tensor([[3.]], dtype=torch.float64)
# LEYE tensor([[0.8152]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8105]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.7036]]) tensor([[2.4495]], dtype=torch.float64)
# SPCOR tensor([[0.7680]]) tensor([[5.0990]], dtype=torch.float64)
# 4 torch.Size([1, 167, 512, 512]) torch.Size([1, 167, 512, 512])
# 19
# (1, 20, 167, 512, 512)
# BSTEM tensor([[0.7603]]) tensor([[4.1231]], dtype=torch.float64)
# LLENS tensor([[0.5970]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.6044]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9116]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.5477]]) tensor([[2.]], dtype=torch.float64)
# ROPTIC tensor([[0.5783]]) tensor([[1.7321]], dtype=torch.float64)
# LPAR tensor([[0.8810]]) tensor([[2.8284]], dtype=torch.float64)
# RPAR tensor([[0.8798]]) tensor([[3.1623]], dtype=torch.float64)
# LEYE tensor([[0.7967]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8299]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.7046]]) tensor([[2.8284]], dtype=torch.float64)
# SPCOR tensor([[0.7429]]) tensor([[5.]], dtype=torch.float64)
# 4 torch.Size([1, 147, 512, 512]) torch.Size([1, 147, 512, 512])
# 19
# (1, 20, 147, 512, 512)
# BSTEM tensor([[0.7283]]) tensor([[4.6904]], dtype=torch.float64)
# LLENS tensor([[0.5324]]) tensor([[2.]], dtype=torch.float64)
# RLENS tensor([[0.5512]]) tensor([[2.2361]], dtype=torch.float64)
# MAND tensor([[0.8829]]) tensor([[1.4142]], dtype=torch.float64)
# LOPTIC tensor([[0.4990]]) tensor([[6.]], dtype=torch.float64)
# ROPTIC tensor([[0.5456]]) tensor([[5.0396]], dtype=torch.float64)
# LPAR tensor([[0.8204]]) tensor([[4.]], dtype=torch.float64)
# RPAR tensor([[0.7941]]) tensor([[5.0990]], dtype=torch.float64)
# LEYE tensor([[0.8235]]) tensor([[2.]], dtype=torch.float64)
# REYE tensor([[0.8470]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.7055]]) tensor([[3.4641]], dtype=torch.float64)
# SPCOR tensor([[0.7289]]) tensor([[6.4031]], dtype=torch.float64)
# 4 torch.Size([1, 159, 512, 512]) torch.Size([1, 159, 512, 512])
# 19
# (1, 20, 159, 512, 512)
# BSTEM tensor([[0.8230]]) tensor([[3.]], dtype=torch.float64)
# LLENS tensor([[0.6953]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.7156]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.9268]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.5719]]) tensor([[2.]], dtype=torch.float64)
# ROPTIC tensor([[0.6887]]) tensor([[1.4142]], dtype=torch.float64)
# LPAR tensor([[0.8552]]) tensor([[3.4641]], dtype=torch.float64)
# RPAR tensor([[0.8679]]) tensor([[3.9354]], dtype=torch.float64)
# LEYE tensor([[0.8254]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8091]]) tensor([[2.0236]], dtype=torch.float64)
# SPCOR tensor([[0.7427]]) tensor([[2.8284]], dtype=torch.float64)
# SPCOR tensor([[0.7603]]) tensor([[5.6569]], dtype=torch.float64)
# 4 torch.Size([1, 176, 512, 512]) torch.Size([1, 176, 512, 512])
# 19
# (1, 20, 176, 512, 512)
# BSTEM tensor([[0.7829]]) tensor([[5.0990]], dtype=torch.float64)
# LLENS tensor([[0.2945]]) tensor([[3.6056]], dtype=torch.float64)
# RLENS tensor([[0.4265]]) tensor([[3.]], dtype=torch.float64)
# MAND tensor([[0.9229]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.6031]]) tensor([[1.7321]], dtype=torch.float64)
# ROPTIC tensor([[0.6591]]) tensor([[2.1889]], dtype=torch.float64)
# LPAR tensor([[0.8439]]) tensor([[3.]], dtype=torch.float64)
# RPAR tensor([[0.8366]]) tensor([[15.1525]], dtype=torch.float64)
# LEYE tensor([[0.8441]]) tensor([[2.1298]], dtype=torch.float64)
# REYE tensor([[0.8748]]) tensor([[2.2361]], dtype=torch.float64)
# SPCOR tensor([[0.6757]]) tensor([[9.4472]], dtype=torch.float64)
# SPCOR tensor([[0.6721]]) tensor([[12.0416]], dtype=torch.float64)
# 4 torch.Size([1, 156, 512, 512]) torch.Size([1, 156, 512, 512])
# 19
# (1, 20, 156, 512, 512)
# BSTEM tensor([[0.7954]]) tensor([[3.6056]], dtype=torch.float64)
# LLENS tensor([[0.5461]]) tensor([[2.]], dtype=torch.float64)
# RLENS tensor([[0.5409]]) tensor([[2.0590]], dtype=torch.float64)
# MAND tensor([[0.9370]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.5390]]) tensor([[2.2361]], dtype=torch.float64)
# ROPTIC tensor([[0.5969]]) tensor([[1.7321]], dtype=torch.float64)
# LPAR tensor([[0.8355]]) tensor([[11.7111]], dtype=torch.float64)
# RPAR tensor([[0.8607]]) tensor([[2.2361]], dtype=torch.float64)
# LEYE tensor([[0.8319]]) tensor([[2.]], dtype=torch.float64)
# REYE tensor([[0.8478]]) tensor([[2.]], dtype=torch.float64)
# SPCOR tensor([[0.7152]]) tensor([[2.4495]], dtype=torch.float64)
# SPCOR tensor([[0.7454]]) tensor([[5.0990]], dtype=torch.float64)
# 4 torch.Size([1, 170, 512, 512]) torch.Size([1, 170, 512, 512])
# 19
# (1, 20, 170, 512, 512)
# BSTEM tensor([[0.7776]]) tensor([[4.]], dtype=torch.float64)
# LLENS tensor([[0.5909]]) tensor([[2.]], dtype=torch.float64)
# RLENS tensor([[0.6916]]) tensor([[1.4142]], dtype=torch.float64)
# MAND tensor([[0.8948]]) tensor([[1.4142]], dtype=torch.float64)
# LOPTIC tensor([[0.5330]]) tensor([[5.4312]], dtype=torch.float64)
# ROPTIC tensor([[0.5790]]) tensor([[2.2361]], dtype=torch.float64)
# LPAR tensor([[0.7539]]) tensor([[6.4031]], dtype=torch.float64)
# RPAR tensor([[0.8208]]) tensor([[5.3852]], dtype=torch.float64)
# LEYE tensor([[0.8287]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8074]]) tensor([[2.2361]], dtype=torch.float64)
# SPCOR tensor([[0.7190]]) tensor([[2.4495]], dtype=torch.float64)
# SPCOR tensor([[0.7588]]) tensor([[6.3246]], dtype=torch.float64)
# 4 torch.Size([1, 176, 512, 512]) torch.Size([1, 176, 512, 512])
# 19
# (1, 20, 176, 512, 512)
# BSTEM tensor([[0.7550]]) tensor([[4.5826]], dtype=torch.float64)
# LLENS tensor([[0.6432]]) tensor([[1.7321]], dtype=torch.float64)
# RLENS tensor([[0.6352]]) tensor([[2.]], dtype=torch.float64)
# MAND tensor([[0.9222]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.5826]]) tensor([[2.]], dtype=torch.float64)
# ROPTIC tensor([[0.5585]]) tensor([[1.7321]], dtype=torch.float64)
# LPAR tensor([[0.8409]]) tensor([[26.0672]], dtype=torch.float64)
# RPAR tensor([[0.7683]]) tensor([[9.0222]], dtype=torch.float64)
# LEYE tensor([[0.8781]]) tensor([[2.2361]], dtype=torch.float64)
# REYE tensor([[0.8916]]) tensor([[2.2361]], dtype=torch.float64)
# SPCOR tensor([[0.6822]]) tensor([[3.3166]], dtype=torch.float64)
# SPCOR tensor([[0.6890]]) tensor([[6.4807]], dtype=torch.float64)
# 4 torch.Size([1, 136, 512, 512]) torch.Size([1, 136, 512, 512])
# 19
# (1, 20, 136, 512, 512)
# BSTEM tensor([[0.8094]]) tensor([[3.3166]], dtype=torch.float64)
# LLENS tensor([[0.6716]]) tensor([[1.4142]], dtype=torch.float64)
# RLENS tensor([[0.7216]]) tensor([[1.7321]], dtype=torch.float64)
# MAND tensor([[0.9120]]) tensor([[1.]], dtype=torch.float64)
# LOPTIC tensor([[0.5281]]) tensor([[2.]], dtype=torch.float64)
# ROPTIC tensor([[0.6201]]) tensor([[1.4142]], dtype=torch.float64)
# LPAR tensor([[0.8444]]) tensor([[5.0990]], dtype=torch.float64)
# RPAR tensor([[0.8877]]) tensor([[3.]], dtype=torch.float64)
# LEYE tensor([[0.8412]]) tensor([[2.]], dtype=torch.float64)
# REYE tensor([[0.8438]]) tensor([[2.2361]], dtype=torch.float64)
# SPCOR tensor([[0.6910]]) tensor([[2.4495]], dtype=torch.float64)
# SPCOR tensor([[0.7380]]) tensor([[6.7082]], dtype=torch.float64)

# %%
len(oars)
# Out:
# 840

# %%
data_ = {}
data_['OAR'] = oars
data_['OAR_Deepmind'] = deep_oars
data_['Patient'] = p_
data_['VolDice'] = dce
data_['95HD'] = hd
data_['SurfDice'] = sd
data_['Observer'] = ob

# %%
data_ = pd.DataFrame.from_dict(data_)
data_.to_csv('/Users/joemarsilla/OARensemble2021_deepmind.csv')
data_
# Out:
#         OAR    OAR_Deepmind    Patient   VolDice      95HD  SurfDice  \
# 0     BSTEM       Brainstem  0522c0427  0.775343  4.123106  1.752673
# 1     LLENS         Lens-Lt  0522c0427  0.459144  2.000000  1.186428
# 2     RLENS         Lens-Rt  0522c0427  0.491228  2.000000  1.168861
# 3      MAND        Mandible  0522c0427  0.901829  2.000000  0.607479
# 4    LOPTIC  Optic-Nerve-Lt  0522c0427  0.500000  2.000000  1.007129
# ..      ...             ...        ...       ...       ...       ...
# 835    RPAR      Parotid-Rt  0522c0161  0.887671  3.000000  0.739405
# 836    LEYE        Orbit-Lt  0522c0161  0.841221  2.000000  0.936999
# 837    REYE        Orbit-Rt  0522c0161  0.843772  2.236068  0.927675
# 838   SPCOR     Spinal-Cord  0522c0161  0.691034  2.449490  1.528939
# 839   SPCOR    Spinal-Canal  0522c0161  0.737972  6.708204  1.127660
#
#          Observer
# 0      oncologist
# 1      oncologist
# 2      oncologist
# 3      oncologist
# 4      oncologist
# ..            ...
# 835  radiographer
# 836  radiographer
# 837  radiographer
# 838  radiographer
# 839  radiographer
#
# [840 rows x 7 columns]

# %%
# IMPORTING data to process...
import pandas as pd
data_=pd.read_csv('/Users/joemarsilla/OARensemble2021_deepmind.csv', index_col=0)
data_[data_['95HD'] > 10]
# images of different sizes (sliding window must be different)
exclude = ['0522c0727b', '0522c0727a']

# %%
fdata = data_[~data_.Patient.isin(exclude)]
exclude = ['Spinal-Canal']
fdata = fdata[~fdata.OAR_Deepmind.isin(exclude)]

# %%
fdata
# Out:
#         OAR    OAR_Deepmind    Patient   VolDice      95HD  SurfDice  \
# 0     BSTEM       Brainstem  0522c0427  0.791135  3.162278  1.596496
# 1     LLENS         Lens-Lt  0522c0427  0.615385  1.648528  0.873513
# 2     RLENS         Lens-Rt  0522c0427  0.532423  2.000000  1.105801
# 3      MAND        Mandible  0522c0427  0.857699  2.000000  0.816564
# 4    LOPTIC  Optic-Nerve-Lt  0522c0427  0.514573  6.352054  1.576920
# ..      ...             ...        ...       ...       ...       ...
# 834    LPAR      Parotid-Lt  0522c0161  0.849112  3.162278  0.886630
# 835    RPAR      Parotid-Rt  0522c0161  0.858814  8.774964  0.841743
# 836    LEYE        Orbit-Lt  0522c0161  0.794831  2.000000  1.088064
# 837    REYE        Orbit-Rt  0522c0161  0.799951  2.000000  1.068180
# 838   SPCOR     Spinal-Cord  0522c0161  0.493133  3.741657  2.475786
#
#          Observer
# 0    radiographer
# 1    radiographer
# 2    radiographer
# 3    radiographer
# 4    radiographer
# ..            ...
# 834    oncologist
# 835    oncologist
# 836    oncologist
# 837    oncologist
# 838    oncologist
#
# [726 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sea
import numpy as np

# %%
# NOT CORRECTED
plt.figure(figsize=(70,40))
sea.set(font_scale=5)  # crazy big
sea.set_style("whitegrid")
sea.set_palette("husl", 2)
plt.title('3D Volumetric Dice (DeepMind Test Set, WOLNET)\n', fontsize=120)
rois = ['MAND', 'LEYE', 'REYE', 'BSTEM', 'SPCOR', 'LPAR', 'RPAR', 'LLENS', 'RLENS', 'LOPTIC', 'ROPTIC']
# rois = ['MAND', 'LEYE', 'REYE', 'BSTEM', 'LARYNX', 'SPCOR', 'LPAR', 'RPAR', 'ESOPH', 'LLENS', 'RLENS', 'LACOU', 'RACOU', 'LPLEX', 'RPLEX', 'LIPS', 'LOPTIC', 'ROPTIC', 'CHIASM']
fdata.OAR = fdata.OAR.astype("category")
fdata.OAR.cat.set_categories(rois, inplace=True)
fdata.sort_values(["OAR"])
medians = fdata.groupby(['OAR'])['VolDice'].median()
vertical_offset = fdata['VolDice'].median() * 0.15 # offset from median for display
ax = sea.boxplot(data=fdata, x="OAR", y="VolDice", hue="Observer", width=.85, linewidth=3) # hue_order=chosen,
ax.set_ylim(0,1)
ax.set_yticklabels(ax.get_yticks(), size = 100)
ax.set_xticklabels(rois, rotation=60, fontsize=80)
ylabels = ['{:,.2f}'.format(x) for x in ax.get_yticks()]
ax.set_yticklabels(ylabels)
for xtick in ax.get_xticks():
    ax.text(xtick,medians[xtick] + vertical_offset, np.round(medians[xtick],2), 
            horizontalalignment='center',size='x-large',color='k',weight='semibold')
# ax.set(xlabel='\nOAR\n', ylabel='3D Volumetric Dice\n')
ax.set_xlabel('\nOAR\n', fontsize=100)
ax.set_ylabel('3D Volumetric Dice\n', fontsize=100)
# ax.legend_.remove()
# Out:
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/categorical.py:2631: FutureWarning: The `inplace` parameter in pandas.Categorical.set_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   res = method(*args, **kwargs)
# /var/folders/4n/x4ks02rx2g9925jn6xb07jkw0000gn/T/ipykernel_1246/1623685893.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(), size = 100)
# /var/folders/4n/x4ks02rx2g9925jn6xb07jkw0000gn/T/ipykernel_1246/1623685893.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ylabels)
# Text(0, 0.5, '3D Volumetric Dice\n')

# %%
plt.figure(figsize=(70,40))
sea.set(font_scale=5)  # crazy big
sea.set_style("whitegrid")
sea.set_palette("husl", 2)
plt.title('95th Percentile Hausdorff Distance (DeepMind Test Set, WOLNET)\n', fontsize=120)
ax = sea.boxplot(data=fdata[fdata["95HD"]<17.5], x="OAR", y="95HD", hue="Observer", width=.85, linewidth=3)
ax.set_ylim(0,18)
ax.set_yticklabels(ax.get_yticks(), size = 100)
ax.set_xticklabels(rois, rotation=60, fontsize=80)
ylabels = ['{:,.0f}'.format(x) for x in ax.get_yticks()]
ax.set_yticklabels(ylabels)
medians = fdata.groupby(['OAR'])['95HD'].median()
vertical_offset = fdata['95HD'].median() * 1.1 # offset from median for display
for xtick in ax.get_xticks():
    ax.text(xtick,medians[xtick] + vertical_offset, np.round(medians[xtick],2), 
            horizontalalignment='center',size='x-large',color='k',weight='semibold')
# ax.set(xlabel='\nOAR\n', ylabel='95%HD\n')
ax.set_xlabel('\nOAR\n', fontsize=100)
ax.set_ylabel('95%HD\n', fontsize=100)
# ax.legend_.remove()
# Out:
# /var/folders/4n/x4ks02rx2g9925jn6xb07jkw0000gn/T/ipykernel_1246/3721625884.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(), size = 100)
# /var/folders/4n/x4ks02rx2g9925jn6xb07jkw0000gn/T/ipykernel_1246/3721625884.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ylabels)
# Text(0, 0.5, '95%HD\n')

# %%
targ = sitk.ReadImage('/Users/joemarsilla/Documents/DeepMind/oncologist/0522c0659/CT_IMAGE.nrrd')

# %%
a = sitk.StatisticsImageFilter()

# %%
a.GetMinimum()
# Out:
# -1024.0

# %%
a.Execute(targ)

# %%
img = sitk.ReadImage('/Users/joemarsilla/Documents/DeepMind/oncologist/0522c0773/CT_IMAGE.nrrd')

# %%
img = sitk.ReadImage('/Users/joemarsilla/Documents/DeepMind/oncologist/0522c0727b/CT_IMAGE.nrrd')

# %%
img.GetSpacing()
# Out:
# (0.9765625, 0.9765625, 2.5)

# %%
path_
# Out:
# '/Users/joemarsilla/Documents/DeepMind/oncologist/0522c0773/segmentations/'

# %%
outputs = torch.from_numpy(np.load(out_path))
targets = torch.from_numpy(np.load(out_path.replace('outs', 'targ')))
outputs, _ = onehot(outputs, targets, argmax=False)
# Out:
# tensor(1)

# %%
outputs.size()
# Out:
# torch.Size([1, 2, 213, 497, 497])

# %%
dce = met.compute_meandice(outs[0], targ[0])

# %%
dce[0][0]
# Out:
# tensor(nan)

# %%
h = met.compute_hausdorff_distance(outs.unsqueeze(0).unsqueeze(0), targ.unsqueeze(0).unsqueeze(0), percentile=95, include_background=True)

# %%
h[0][0].item()
# Out:
# 5.0990195135927845

# %%
targets.shape
# Out:
# torch.Size([213, 497, 497])

# %%
targ = sitk.ReadImage(path_+deep_classes[k]+'.nrrd')

# %%
targ.GetSpacing()
# Out:
# (0.97, 0.97, 2.5)

# %%
out_path = f"/Users/joemarsilla/Downloads/deepmind_data_ensemble/outs_{i}_FULL.npy"
outputs = torch.from_numpy(np.load(out_path))

# %%
outputs.max()
# Out:
# tensor(19.)

# %%
import glob
ims = glob.glob('/Users/joemarsilla/Downloads/deepmind_ensemble/in*')

# %%
for path in ims:
    a = np.load(path)
    print(a.shape, path)
# Out:
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_8_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_9_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_17_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_16_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_29_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_28_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_2_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_3_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_23_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_22_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_34_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_33_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_32_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_10_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_11_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_5_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_4_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_24_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_25_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_1_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_0_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_20_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_21_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_14_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_15_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_6_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_7_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_19_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_18_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_27_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_26_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_13_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_12_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_30_FULL.npy
# (170, 512, 512) /Users/joemarsilla/Downloads/deepmind_ensemble/input_31_FULL.npy
